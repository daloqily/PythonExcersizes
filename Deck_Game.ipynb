# %% [markdown]
# <a href="https://colab.research.google.com/github/daloqily/PythonExcersizes/blob/main/Deck_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import shuffle

##-----------------from resource-----------------------##
class Card:

  ## suits&value are represented by int

  suits = ["spades",
             "hearts",
             "diamonds",
             "clubs"]
    
    values = [None, None,"2", "3",
              "4", "5", "6", "7",
              "8", "9", "10",
              "Jack", "Queen",
              "King", "Ace"]

    def __init__(self, v,s):
      self.v = v
      self.s = s

##  magic functions that enables python to compare self defined objects
      ##less than##
    def __lt__(self, c2):
        if self.value < c2.value:
            return True
        if self.value == c2.value:
            if self.suit < c2.suit:
                return True
            else:
                return False
        return False
      ##greater than##
    def __gt__(self, c2):
        if self.value > c2.value:
            return True
        if self.value == c2.value:
            if self.suit > c2.suit:
                return True
            else:
                return False
        return False

## method that python interperets when printing a self-defined object
    def __Str__(self):
      v = self.values[self.value] +\
          " of " + \
            self.suits[self.suit]
            print(v)
      

##-------------------from resource------------------------##
class Deck:
    def __init__(self):
        self.cards = []
        for i in range(2, 15):
            for j in range(4):
                self.cards\
                    .append(Card(i,
                                 j))
        shuffle(self.cards)

    def rm_card(self):
        if len(self.cards) == 0:
            return
        return self.cards.pop()


##-------------------------------------------------##

class Player:
  def __init__(self, name):
    self.name = name
    self.wins_round = 0
    

  def __str__(self):
        return 'name='+self.name+' wins per round=$'+str(self.wins_round)

##-------------------------------------------------##

class Game:

  def __init__(self , num_players , players):
    self.round = 0
    self.num_players = num_players
    self.players=players

  def switch_turn(current_player):
    len = len(players)
    for i in len:
      if players[len-1] == current_player:
        round+=1;
        print("new round")
        current_player = players[0] 
        return current_player # return new round indicator
      elif players[i] == current_player:
        current_player = players[i+1]
  

  def draw_card(current_player):
    card = cards[rand[0:9]]
    #score = card.score
    return card

  def check_deck(self):
    if deck.len()==0:
      return true
    else
    return false

 def highest_score(players):

   for i in players.len():
     if player[i+1].score >= players[i]:
       highest = player[i+1]

  return highest


  


  def play_game(self, current_player):
    
    #switch players for taking turns
    if(switch_turn(current_player)== players[0]):
      print("new round")
      highest_score() 
    else:
      current_player = switch_turn(current_player)
    
  current_player.score = draw_card().score

  if (check_deck):
    #check highest_score
  else:
    switch_turn()






#----------------------------by dana-----------------------#

def main:
  players=[]
  num_players=input("How many players?:")
  print("\n")
  
  for i in num_player-1:
    print(f"Player {i+1}:")
    players[i]=Player(input("Enter your name: "))
    print("\n")

   
  while True:

    #Start the game
    game=Game(num_players, players)
    current_player = players[0]

    #Player choice menu
    print("Turn to choose for", current_player.name)
    print("Enter 1 to draw a card")
    print("Enter 2 to Quit")


    # Try block for handling user choices
    try:
      choice = int(input())
    except ValueError:
      print("Incorrect input! please choose from the list")
      continue


    # conditions of player choice
    if choice == 1:
     current_player
      if current_player == player1:
        player_choice['O'] = player2
      else:
        player_choice['O'] = player1

    elif choice == 2:
      player_choice['O'] = current_player
      if current_player == player1:
        player_choice['X'] = player2
      else:
        player_choice['X'] = player1

    elif choice ==3:
      print("Final Scores")
      print_scoreBoard(score_board)
      break
    else:
      print("incorrect choice, try again\n")

    #stroe the winner
    winner = single_game(options[choice-1])

    
    #upadate scoreboard
    if winner != 'D':
       player_won = player_choice[winner]
       score_board[player_won] = score_board[player_won] + 1

    print_scoreBoard(score_board)

    #switch players
    if current_player == player1:
       current_player= player2
    else:
      current_player = player1
